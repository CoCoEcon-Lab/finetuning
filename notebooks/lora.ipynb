# %% [markdown]
# # Fine-tuning with LoRA/qLoRA

# %% [markdown]
# ### Imports and Model/Data Loading

# %%
# standardlib imports
import os
from pathlib import Path

# Third party imports
from transformers import AutoTokenizer, AutoModelForCausalLM

# Package imports (you can ignore these)
from finetuning._defaults import MODEL_DEFAULTS
from finetuning._utils import setup_hf

# %%
# Load model
